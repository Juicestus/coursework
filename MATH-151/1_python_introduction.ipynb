# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = sp.symbols('x')
f = sp.E ** x
display(f)
# Out:
# exp(x)

# %%
# display(f.subs('x', 2))
# display(f.subs('x', 2).evalf())

# %%
g = -sp.Rational(1, 4) * sp.log(16*x)

# %%
sp.plot(f, (x, -2.0, 2.0))

# %%
# for i in range(10, 100000, 100):
i = 1_000_000_000_000_000_000_000_000_000_000_000_000_000_000_000_000_000_000
K=[i]
while K[-1]>1:
    if K[-1] % 2 == 0:
        K.append(K[-1]/2)
    else:
        K.append(3*K[-1]+1)
plt.plot(range(0, len(K)), K)
# Out:
# 54.0
