# %% [markdown]
# ## MATH 151 Lab  2

# %% [markdown]
# Put team members' names and section number here.

# %%
import sympy as sp
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# Instructions: Complete the lab assignment in your assigned groups. Unless stated otherwise, your answers should be obtained using Python code.
#
# Do not modify the cell above, as it contains all the packages you will need. It is highly recommended to not use any additional packages.

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
#start code here
x = sp.Symbol('x')
f = (3**(4(x-2))-1)/()

# %% [markdown]
# #### 1b

# %%
#start code here

# %% [markdown]
# #### 1c

# %%
#start code here

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
#start code here

# %% [markdown]
# #### 2b

# %%
# Write your answer as comments here. Make sure all text is visible when printing the PDF!

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
#start code here

# %% [markdown]
# #### 3b

# %%
#start code here

# %% [markdown]
# ## Only run this block of code when you are ready to make your PDF!
#
# First, make sure your lab template is located in the main folder of your Google Drive. If it is located in another folder, you'll need to edit the location in the code below to match your file's location.
#
# Second, Make sure the file names given in the code below match the name of this notebook! If they don't, be sure to edit the names.
#
# Then, when you are ready to make your PDF, run this code.
#
# Google will ask for permission to open Google Drive. At least check the two boxes with the Google Drive logo next to them before continuing.
#
# The rest of the process WILL take several minutes, so be patient!
#
# When it is done, the PDF file will be in the same location as your notebook.

# %%
# %%capture
from google.colab import drive
drive.mount("/content/drive")

# !pip install nbconvert
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc

# %cd /content/drive/MyDrive/

# !jupyter nbconvert --to pdf "Lab2_151temp_24C.ipynb" --output "Lab2_151temp_24C.pdf"
