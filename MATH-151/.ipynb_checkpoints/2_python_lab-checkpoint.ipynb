# %% [markdown]
# ## MATH 151 Lab  1

# %% [markdown]
# Put team members' names and section number here.

# %%
import sympy as sp
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
# put your code here

# %%
# put your code here

# %% [markdown]
# #### 1b

# %%
# put your code here

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
# put your code here

# %% [markdown]
# #### 2b

# %%
# put your code here

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
# put your code here

# %% [markdown]
# #### 3b

# %%
# put your code here

# %% [markdown]
# #### 3c

# %%
# put your code here

# %% [markdown]
# #### 3d

# %%
# put your code here

# %% [markdown]
# #### 3e

# %%
# put your code here

# %% [markdown]
# #### 3f

# %%
# put your code here
